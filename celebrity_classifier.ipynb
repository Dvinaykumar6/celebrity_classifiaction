# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\vinay\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\vinay\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
# !pip install matplotlib
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in c:\users\vinay\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vinay\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\vinay\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
img = cv2.imread('Model/dataset/virat_kohli/17kohli1.jpg')
img.shape
# Out:
# (1088, 1200, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1088, 1200)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('Model/opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('Model/opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[538, 189, 199, 199]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (538, 189, 199, 199)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    # Check if the image file exists before attempting to read it
    if not os.path.exists(image_path):
        print(f"Error: Image file not found at {image_path}")
        return None

    img = cv2.imread(image_path)

    # Check if the image was loaded successfully
    if img is None:
        print(f"Error: Failed to load image from {image_path}")
        return None

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
path_to_data = "Model/dataset"
path_to_cr_data = "Model/dataset\\cropped"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['Model/dataset\\anirudh',
#  'Model/dataset\\cropped',
#  'Model/dataset\\jr_ntr',
#  'Model/dataset\\narendra_modi',
#  'Model/dataset\\rajamouli',
#  'Model/dataset\\virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('\\')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data +"/"+celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# anirudh
# Generating cropped images in folder:  Model/dataset\cropped/anirudh
# cropped
# Error: Failed to load image from Model/dataset\cropped\anirudh
# jr_ntr
# Generating cropped images in folder:  Model/dataset\cropped/jr_ntr
# narendra_modi
# Generating cropped images in folder:  Model/dataset\cropped/narendra_modi
# Error: Failed to load image from Model/dataset\narendra_modi\94272552.jpg
# rajamouli
# Generating cropped images in folder:  Model/dataset\cropped/rajamouli
# virat_kohli
# Generating cropped images in folder:  Model/dataset\cropped/virat_kohli
# Error: Failed to load image from Model/dataset\virat_kohli\1678836965_57c7769197215ff88fbbb4b52c34856d.gif

# %%
# Wavelet transform
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'anirudh': ['Model/dataset\\cropped/anirudh\\anirudh10.png',
#   'Model/dataset\\cropped/anirudh\\anirudh11.png',
#   'Model/dataset\\cropped/anirudh\\anirudh14.png',
#   'Model/dataset\\cropped/anirudh\\anirudh15.png',
#   'Model/dataset\\cropped/anirudh\\anirudh16.png',
#   'Model/dataset\\cropped/anirudh\\anirudh17.png',
#   'Model/dataset\\cropped/anirudh\\anirudh18.png',
#   'Model/dataset\\cropped/anirudh\\anirudh19.png',
#   'Model/dataset\\cropped/anirudh\\anirudh2.png',
#   'Model/dataset\\cropped/anirudh\\anirudh20.png',
#   'Model/dataset\\cropped/anirudh\\anirudh23.png',
#   'Model/dataset\\cropped/anirudh\\anirudh24.png',
#   'Model/dataset\\cropped/anirudh\\anirudh26.png',
#   'Model/dataset\\cropped/anirudh\\anirudh27.png',
#   'Model/dataset\\cropped/anirudh\\anirudh28.png',
#   'Model/dataset\\cropped/anirudh\\anirudh29.png',
#   'Model/dataset\\cropped/anirudh\\anirudh30.png',
#   'Model/dataset\\cropped/anirudh\\anirudh31.png',
#   'Model/dataset\\cropped/anirudh\\anirudh32.png',
#   'Model/dataset\\cropped/anirudh\\anirudh34.png',
#   'Model/dataset\\cropped/anirudh\\anirudh35.png',
#   'Model/dataset\\cropped/anirudh\\anirudh37.png',
#   'Model/dataset\\cropped/anirudh\\anirudh38.png',
#   'Model/dataset\\cropped/anirudh\\anirudh39.png',
#   'Model/dataset\\cropped/anirudh\\anirudh40.png',
#   'Model/dataset\\cropped/anirudh\\anirudh41.png',
#   'Model/dataset\\cropped/anirudh\\anirudh42.png',
#   'Model/dataset\\cropped/anirudh\\anirudh43.png',
#   'Model/dataset\\cropped/anirudh\\anirudh44.png',
#   'Model/dataset\\cropped/anirudh\\anirudh45.png',
#   'Model/dataset\\cropped/anirudh\\anirudh46.png',
#   'Model/dataset\\cropped/anirudh\\anirudh47.png',
#   'Model/dataset\\cropped/anirudh\\anirudh48.png',
#   'Model/dataset\\cropped/anirudh\\anirudh5.png',
#   'Model/dataset\\cropped/anirudh\\anirudh50.png',
#   'Model/dataset\\cropped/anirudh\\anirudh51.png',
#   'Model/dataset\\cropped/anirudh\\anirudh52.png',
#   'Model/dataset\\cropped/anirudh\\anirudh53.png',
#   'Model/dataset\\cropped/anirudh\\anirudh6.png',
#   'Model/dataset\\cropped/anirudh\\anirudh7.png',
#   'Model/dataset\\cropped/anirudh\\anirudh8.png',
#   'Model/dataset\\cropped/anirudh\\anirudh9.png'],
#  'jr_ntr': ['Model/dataset\\cropped/jr_ntr\\jr_ntr1.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr10.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr12.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr14.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr15.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr16.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr17.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr18.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr19.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr20.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr21.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr22.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr23.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr24.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr25.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr26.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr27.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr28.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr29.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr3.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr30.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr31.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr32.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr33.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr34.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr35.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr36.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr37.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr38.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr39.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr4.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr40.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr41.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr42.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr43.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr45.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr46.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr49.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr5.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr50.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr51.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr52.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr53.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr54.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr55.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr56.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr58.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr6.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr60.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr61.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr62.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr63.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr64.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr65.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr66.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr67.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr69.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr7.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr8.png',
#   'Model/dataset\\cropped/jr_ntr\\jr_ntr9.png'],
#  'narendra_modi': ['Model/dataset\\cropped/narendra_modi\\narendra_modi1.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi10.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi12.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi13.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi14.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi16.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi17.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi19.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi20.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi22.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi23.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi24.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi25.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi26.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi27.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi28.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi29.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi3.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi30.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi31.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi32.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi4.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi5.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi6.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi7.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi8.png',
#   'Model/dataset\\cropped/narendra_modi\\narendra_modi9.png'],
#  'rajamouli': ['Model/dataset\\cropped/rajamouli\\rajamouli1.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli10.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli11.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli12.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli13.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli14.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli15.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli17.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli18.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli19.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli2.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli20.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli21.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli22.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli23.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli24.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli25.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli26.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli27.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli29.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli3.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli30.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli31.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli32.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli34.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli35.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli36.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli37.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli40.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli43.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli44.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli45.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli46.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli47.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli48.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli5.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli50.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli51.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli53.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli55.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli56.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli57.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli58.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli61.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli62.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli65.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli66.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli67.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli7.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli70.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli71.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli72.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli73.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli74.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli75.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli77.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli78.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli79.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli8.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli80.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli81.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli83.png',
#   'Model/dataset\\cropped/rajamouli\\rajamouli9.png'],
#  'virat_kohli': ['Model/dataset\\cropped/virat_kohli\\virat_kohli1.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli10.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli11.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli12.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli15.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli16.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli17.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli18.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli19.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli2.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli20.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli21.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli22.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli23.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli24.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli25.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli26.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli27.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli28.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli29.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli3.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli30.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli31.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli32.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli33.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli34.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli35.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli36.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli4.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli5.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli6.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli7.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli8.png',
#   'Model/dataset\\cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'anirudh': 0,
#  'jr_ntr': 1,
#  'narendra_modi': 2,
#  'rajamouli': 3,
#  'virat_kohli': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 226

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (226, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8596491228070176

# %%
len(X_test)
# Out:
# 57

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.875223
# 1        random_forest    0.756506
# 2  logistic_regression    0.869519
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8596491228070176

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7543859649122807

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9298245614035088

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 6,  0,  1,  1,  1],
#        [ 0, 12,  0,  1,  0],
#        [ 0,  0,  5,  0,  0],
#        [ 0,  0,  0, 24,  0],
#        [ 0,  0,  0,  0,  6]], dtype=int64)

# %%
class_dict
# Out:
# {'anirudh': 0,
#  'jr_ntr': 1,
#  'narendra_modi': 2,
#  'rajamouli': 3,
#  'virat_kohli': 4}

# %%
## Saving the best model
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\vinay\anaconda3\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
